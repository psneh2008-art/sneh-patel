# %%
class Person:
    def __init__(self,name,age):
          self.name=name
          self.age=age
class Empolyee(Person):
    def __init__(self,name,age,id,salry):
        super().__init__(name,age)
        self.id=id

        self.salry=salry
class Manager(Empolyee):
    def __init__(self,name,age,id,salry,dep):
        self.dep=dep
        super().__init__(name,age,id,salry)
  
class developer(Empolyee):
    def __init__(self,name,age,id,salry, dep,subject):
        self.subject=subject
        super().__init__(name,age,id,salry,dep)
Employee_Mangement_systeam=[]
Name=[]
Age=[]
Id=[]
Salry=[]
Dep=[]
Sub=[]
          
print("-"*3,"Python OOP Project: Employee Mangement systeam","-"*3)
print("Chose an option :\n1.Create a person\n2.Create an Employee\n3.Create a Maneger\n4. Show details \n5. Compaiar Salary \n6.Exit ")

choise= int(input("Enter your choise:"))
while True:
    if (choise == 1):
        a= input("Enter Name:")
        b= int(input("Enter Age:"))
        p=Person(a,b)
        print(f"Person created with Name:{p.name} and Age:{p.age}")
        Age.append(p.age)
        Name.append(p.name)
        print("-"*3,"Choose another Opition", "-"*3)
        print("Chose an option :\n1.Create a person\n2.Create an Employee\n3.Create a Maneger\n4. Show details \n5. Compaiar Salary \n6.Exit ")
        choise= int(input("Enter your choise:"))
    elif (choise == 2):
     a= input("Enter Name:")
     b= int(input("Enter Age:"))
     c= input(" Enter Employee Id:")
     d= int(input("Enter your Salary:"))
     p=Empolyee(a,b,c,d)
     print(f"Employee created with Name:{p.name},Age:{p.age},Empolyee ID :{p.id},and Salary:${p.salry}")
     Age.append(p.age)
     Name.append(p.name)
     Id.append(p.id)
     Salry.append(p.salry)
     print("-"*3,"Choose another Opition", "-"*3)
     print("Chose an option :\n1.Create a person\n2.Create an Employee\n3.Create a Maneger\n4. Show details \n5. Compaiar Salary \n6.Exit ")
     choise= int(input("Enter your choise:"))
    elif (choise == 3):
     a= input("Enter Name:")
     b= int(input("Enter Age:"))
     c= input(" Enter Employee Id:")
     d= int(input("Enter your Salary:"))
     e= input("Enter your Department:")
     p=Manager(a,b,c,d,e)
     print(f"Manager created with Name:{p.name},Age:{p.age},Empolyee ID :{p.id},Salary:${p.salry},Department:{p.dep}")
     Age.append(p.age)
     Name.append(p.name)
     Id.append(p.id)
     Salry.append(p.salry)
     Dep.append(p.dep)
     print("-"*3,"Choose another Opition", "-"*3)
     print("Chose an option :\n1.Create a person\n2.Create an Employee\n3.Create a Maneger\n4. Show details \n5. Compaiar Salary \n6.Exit ")
     choise= int(input("Enter your choise:"))
    elif (choise == 4):
            print("Chose details to show:\n1.Person\n2.Empolyee\n3.manager")
            preea=int(input("Enter your choise:"))
            if preea==1:
              print(f"Person Details:\nName:{p.name} and Age:{p.age}")
            elif preea==2:
                print(f"Employee Details : \nName:{p.name},\nAge:{p.age},\nEmpolyee ID :{p.id},\nand Salary:${p.salry}")
            elif preea==3:
                print(f"Manager Details :\nName : {p.name},\nAge:{p.age},\nEmpolyee ID :{p.id},\nSalary:${p.salry}")
            print("-"*3,"Choose another Opition", "-"*3)
            print("Chose an option :\n1.Create a person\n2.Create an Employee\n3.Create a Maneger\n4. Show details \n5. Compaiar Salary \n6.Exit ")
            choise= int(input("Enter your choise:"))
    elif (choise == 5):
        print("welcome in Employe salry compair systeam:")
        E_id=input("Enter fist Employee ID to compaire :")
        E_id2=input("Enter second  Employee ID to compaire :")
        if E_id in Id :
            E1_name=Name[(Id.index(E_id))+1]
            E2_name=Name[(Id.index(E_id2))+1]
            E1_salry=Salry[Id.index(E_id)]
            E2_salry=Salry[Id.index(E_id2)]
            if E1_salry>E2_salry:
                print(f"{E2_name} has lower salry then {E1_name}")
            else:
                print(f"{E1_name} has lower salry then {E2_name}")    
        else:
            print("You have put the wrong Employee Id ")        
        
        print("-"*3,"Choose another Opition", "-"*3)
        print("Chose an option :\n1.Create a person\n2.Create an Employee\n3.Create a Maneger\n4. Show details \n5. Compaiar Salary \n6.Exit ")
        choise= int(input("Enter your choise:"))
    elif (choise == 6):
        print("Exiting the system. All resorce has been freed.\n \nGoodbye!")
        break
# Out:
# --- Python OOP Project: Employee Mangement systeam ---
# Chose an option :
# 1.Create a person
# 2.Create an Employee
# 3.Create a Maneger
# 4. Show details
# 5. Compaiar Salary
# 6.Exit
# Enter your choise: 6
# Exiting the system. All resorce has been freed.
#
# Goodbye!
